# %%
#Data & Frame
import pandas as pd
import numpy as np
import yfinance as yf

#Visualization
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import seaborn as sns

# For data modeling
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# For metrics and helpful functions
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.tree import plot_tree

# For saving models
import pickle

import warnings

# %%
# Suppress all warnings
warnings.filterwarnings("ignore")

# Display all columns in a dataset
pd.set_option('display.max_columns',None)

# %%
sector_data = pd.read_csv('/Users/xonkar/Desktop/Data_Projects/Options/Technology/Structured_Data.csv')
sector_data
# Out:
#      CreatedDate CreatedTime Symbol   Type  Volume  Price Side Money CallPut  \
# 0     2023-01-09  3:59:57 PM   MSFT  SWEEP     200   6.75    A   OTM    CALL
# 1     2023-01-09  3:59:44 PM   BABA  BLOCK     304   3.90    B   OTM    CALL
# 2     2023-01-09  3:58:22 PM   NVDA  BLOCK     250   8.46    B   ITM    CALL
# 3     2023-01-09  3:58:16 PM   BABA  SWEEP     500  14.85    B   ITM    CALL
# 4     2023-01-09  3:58:05 PM   BABA  SWEEP     250  14.88    B   ITM    CALL
# ...          ...         ...    ...    ...     ...    ...  ...   ...     ...
# 1298  2023-01-09  9:30:02 AM    CRM  BLOCK    1000  21.90    B   OTM    CALL
# 1299  2023-01-09  9:30:00 AM   AAPL    ML/     999   6.15    B   OTM    CALL
# 1300  2023-01-09  9:30:00 AM   AAPL    ML/     999  10.25   BB   ATM     PUT
# 1301  2023-01-09  9:30:00 AM    AMD    ML/     998   4.78    A   ITM     PUT
# 1302  2023-01-09  9:30:00 AM    AMD    ML/     997  12.32    B   OTM     PUT
#
#       Strike    Spot  Premium ExpirationDate    Color  ImpliedVolatility  Dte  \
# 0      235.0  227.14   135000     2023-02-17    WHITE               0.33   39
# 1      121.0  110.84   118560     2023-02-10   YELLOW               0.58   32
# 2      150.0  156.19   211500     2023-01-13  MAGENTA               0.74    4
# 3      100.0  110.92   742522     2023-02-17    WHITE               0.59   39
# 4      100.0  110.92   371961     2023-02-17    WHITE               0.59   39
# ...      ...     ...      ...            ...      ...                ...  ...
# 1298   150.0  143.53  2190000     2024-01-19   YELLOW               0.39  375
# 1299   145.0  130.70   614555     2023-06-16    WHITE               0.32  157
# 1300   130.0  130.70  1023805     2023-06-16    WHITE               0.33  157
# 1301    70.0   66.00   477041     2023-01-20    WHITE               0.49   11
# 1302    65.0   66.06  1228304     2024-06-21    WHITE               0.46  528
#
#      ER StockEtf                  Sector Uoa Weekly         MktCap     OI  \
# 0     F    STOCK  Information Technology   F      F  1676733000000  16193
# 1     F    STOCK  Information Technology   F      F   291151000000     23
# 2     F    STOCK  Information Technology   F      T   365531000000   3918
# 3     F    STOCK  Information Technology   F      F   291151000000   9468
# 4     F    STOCK  Information Technology   F      F   291151000000   9468
# ...  ..      ...                     ...  ..    ...            ...    ...
# 1298  F    STOCK  Information Technology   F      F   140510000000    755
# 1299  F    STOCK  Information Technology   F      F  2062010000000  13919
# 1300  F    STOCK  Information Technology   F      F  2062010000000  71667
# 1301  F    STOCK  Information Technology   F      F   103126000000  61125
# 1302  F    STOCK  Information Technology   F      F   103126000000   2366
#
#         1D After    3D After    5D After  1D Price  3D Price  5D Price  \
# 0     2023-01-10  2023-01-12  2023-01-16    228.85    238.51    240.35
# 1     2023-01-10  2023-01-12  2023-01-16    114.88    113.15    115.19
# 2     2023-01-10  2023-01-12  2023-01-16    159.09    165.11    177.02
# 3     2023-01-10  2023-01-12  2023-01-16    114.88    113.15    115.19
# 4     2023-01-10  2023-01-12  2023-01-16    114.88    113.15    115.19
# ...          ...         ...         ...       ...       ...       ...
# 1298  2023-01-10  2023-01-12  2023-01-16    147.44    149.60    148.47
# 1299  2023-01-10  2023-01-12  2023-01-16    130.73    133.41    135.94
# 1300  2023-01-10  2023-01-12  2023-01-16    130.73    133.41    135.94
# 1301  2023-01-10  2023-01-12  2023-01-16     68.05     70.80     71.59
# 1302  2023-01-10  2023-01-12  2023-01-16     68.05     70.80     71.59
#
#       1D Performance  3D Performance  5D Performance  Distance       1PN  \
# 0               0.75            5.01            5.82      3.46  positive
# 1               3.65            2.09            3.93      9.17  positive
# 2               1.86            5.71           13.34     -3.96  positive
# 3               3.57            2.01            3.85     -9.84  positive
# 4               3.57            2.01            3.85     -9.84  positive
# ...              ...             ...             ...       ...       ...
# 1298            2.72            4.23            3.44      4.51  positive
# 1299            0.02            2.07            4.01     10.94  positive
# 1300            0.02            2.07            4.01     -0.54  positive
# 1301            3.11            7.27            8.47      6.06  positive
# 1302            3.00            7.17            8.36     -1.61  positive
#
#            3PN       5PN WeekDay
# 0     positive  positive  Monday
# 1     positive  positive  Monday
# 2     positive  positive  Monday
# 3     positive  positive  Monday
# 4     positive  positive  Monday
# ...        ...       ...     ...
# 1298  positive  positive  Monday
# 1299  positive  positive  Monday
# 1300  positive  positive  Monday
# 1301  positive  positive  Monday
# 1302  positive  positive  Monday
#
# [1303 rows x 37 columns]

# %% [markdown]
# ## Check Stats and Corresponding Flow

# %%
sector_data.describe()
# Out:
#              Volume        Price       Strike         Spot       Premium  \
# count   1303.000000  1303.000000  1303.000000  1303.000000  1.303000e+03
# mean     831.721412    23.087475   146.280123   129.300384  1.354432e+06
# std     1516.502288    34.497039   101.125413    91.405175  2.848694e+06
# min       80.000000     0.200000     2.500000     5.060000  1.000000e+05
# 25%      206.000000     4.455000    95.000000    69.795000  1.727360e+05
# 50%      398.000000     9.750000   130.000000   122.400000  3.512340e+05
# 75%      845.500000    28.240000   165.000000   150.860000  1.175628e+06
# max    22046.000000   303.400000   925.000000   917.800000  3.112090e+07
#
#        ImpliedVolatility          Dte        MktCap             OI  \
# count        1303.000000  1303.000000  1.303000e+03    1303.000000
# mean            0.591358    87.839601  6.000706e+11    7317.810437
# std             0.495703   144.422600  7.873026e+11   12745.999311
# min             0.000000     4.000000  0.000000e+00       0.000000
# 25%             0.350000    11.000000  4.648400e+10     614.500000
# 50%             0.520000    39.000000  2.458990e+11    2657.000000
# 75%             0.665000   101.000000  1.036536e+12    8919.500000
# max             4.910000   892.000000  2.062010e+12  100711.000000
#
#           1D Price     3D Price     5D Price  1D Performance  3D Performance  \
# count  1303.000000  1303.000000  1303.000000     1303.000000     1303.000000
# mean    129.743170   133.201443   135.978358        0.588127        2.928281
# std      90.893624    95.198603    96.410166        2.715707        3.990783
# min       5.750000     6.160000     6.180000       -5.000000      -15.170000
# 25%      70.030000    71.800000    75.100000       -0.960000        0.940000
# 50%     126.930000   131.630000   130.620000        0.010000        2.430000
# 75%     154.325000   156.750000   159.800000        1.700000        4.130000
# max     915.780000  1024.310000  1070.000000       23.300000       38.860000
#
#        5D Performance     Distance
# count     1303.000000  1303.000000
# mean         5.270967    18.490629
# std          6.079894    49.565312
# min        -19.790000   -90.770000
# 25%          2.605000    -2.180000
# 50%          4.110000     2.180000
# 75%          7.120000    25.895000
# max         65.330000   532.910000

# %%
# Find the maximum value in the 'Distance' column
max_distance = sector_data['Distance'].max()

# Filter the DataFrame to retrieve rows where the 'Distance' column equals the maximum value
largest_value = sector_data[sector_data['Distance'] == max_distance]

# Print or display the filtered DataFrame
largest_value
# Out:
#     CreatedDate CreatedTime Symbol Type  Volume  Price Side Money CallPut  \
# 376  2023-01-09  2:33:10 PM   DOCU  ML/     290  302.3    B   ITM     PUT
#
#      Strike   Spot  Premium ExpirationDate  Color  ImpliedVolatility  Dte ER  \
# 376   360.0  56.88  8766700     2023-01-20  WHITE                0.0   11  F
#
#     StockEtf                  Sector Uoa Weekly       MktCap   OI    1D After  \
# 376    STOCK  Information Technology   F      F  10966000000  400  2023-01-10
#
#        3D After    5D After  1D Price  3D Price  5D Price  1D Performance  \
# 376  2023-01-12  2023-01-16     58.05      58.7     59.72            2.06
#
#      3D Performance  5D Performance  Distance       1PN       3PN       5PN  \
# 376             3.2            4.99    532.91  positive  positive  positive
#
#     WeekDay
# 376  Monday

# %% [markdown]
# ## Visualize Performance Relation To Two Other Variables

# %%
import plotly.graph_objects as go

# Define hover text with only the Symbol column
hover_text = sector_data['Symbol']

# Define colors based on '5D Performance' values
colors = ['red' if p < 0 else 'green' for p in sector_data['5D Performance']]

# Create a trace for the scatter plot
trace = go.Scatter3d(
    x=sector_data['Distance'],
    y=sector_data['Dte'],
    z=sector_data['5D Performance'],
    mode='markers',
    marker=dict(
        size=5,
        color=colors,           # Set color based on '5D Performance' values
        opacity=0.6             # Marker opacity
    ),
    hovertext=hover_text       # Set hover text to show only Symbol
)

# Create layout for the plot
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='Distance'),
        yaxis=dict(title='Dte'),
        zaxis=dict(title='Performance')
    ),
    title='3D Scatter Plot: Distance vs Dte vs Performance'
)

# Create the figure
fig = go.Figure(data=[trace], layout=layout)

# Show the interactive plot
fig.show()

# %% [markdown]
# ## Scan for Specific Stock Flow

# %%
# Create a filter for the desired stocks
desired_stocks = ['DOCU']  # Replace with the stocks you want to filter
# Filter the DataFrame based on the 'Symbol' column
filtered_df = sector_data[sector_data['Symbol'].isin(desired_stocks)]
filtered_df = filtered_df.reset_index(drop=True)

# Display the filtered DataFrame
filtered_df
# Out:
#    CreatedDate  CreatedTime Symbol Type  Volume   Price Side Money CallPut  \
# 0   2023-01-09   2:46:41 PM   DOCU  ML/     150   20.70    A   ITM     PUT
# 1   2023-01-09   2:46:41 PM   DOCU  ML/     150  303.40    A   ITM     PUT
# 2   2023-01-09   2:46:41 PM   DOCU  ML/     230  243.12    A   ITM     PUT
# 3   2023-01-09   2:46:41 PM   DOCU  ML/     230   23.25    A   ITM     PUT
# 4   2023-01-09   2:37:44 PM   DOCU  ML/     500   43.05    B   ITM     PUT
# 5   2023-01-09   2:37:44 PM   DOCU  ML/    1060   53.18    A   ITM     PUT
# 6   2023-01-09   2:37:44 PM   DOCU  ML/     560  133.30    A   ITM     PUT
# 7   2023-01-09   2:33:10 PM   DOCU  ML/     470  213.67    A   ITM     PUT
# 8   2023-01-09   2:33:10 PM   DOCU  ML/     760   53.15    A   ITM     PUT
# 9   2023-01-09   2:33:10 PM   DOCU  ML/     290  302.30    B   ITM     PUT
# 10  2023-01-09  11:49:06 AM   DOCU  ML/    2222    0.95    A   OTM     PUT
# 11  2023-01-09  11:49:06 AM   DOCU  ML/    2222   12.20    N   ITM    CALL
#
#     Strike   Spot   Premium ExpirationDate    Color  ImpliedVolatility  Dte  \
# 0     77.5  56.90    310500     2023-01-20    WHITE               0.99   11
# 1    360.0  56.90   4551000     2023-01-20  MAGENTA               4.91   11
# 2    300.0  56.90   5591750     2023-01-20   YELLOW               4.08   11
# 3     80.0  56.90    534750     2023-01-20    WHITE               1.13   11
# 4    100.0  56.88   2152500     2023-01-20   YELLOW               1.21   11
# 5    110.0  56.88   5637300     2023-01-20    WHITE               1.81   11
# 6    190.0  56.88   7464800     2023-01-20   YELLOW               3.27   11
# 7    270.0  56.88  10042700     2024-01-19   YELLOW               1.30  375
# 8    110.0  56.88   4039400     2023-01-20    WHITE               1.75   11
# 9    360.0  56.88   8766700     2023-01-20    WHITE               0.00   11
# 10    45.0  56.07    211090     2023-02-17    WHITE               0.69   39
# 11    45.0  56.07   2710840     2023-02-17   YELLOW               0.70   39
#
#    ER StockEtf                  Sector Uoa Weekly       MktCap    OI  \
# 0   F    STOCK  Information Technology   F      F  10966000000   372
# 1   F    STOCK  Information Technology   F      F  10966000000   400
# 2   F    STOCK  Information Technology   F      F  10966000000   206
# 3   F    STOCK  Information Technology   F      F  10966000000   328
# 4   F    STOCK  Information Technology   F      F  10966000000   438
# 5   F    STOCK  Information Technology   F      F  10966000000  2131
# 6   F    STOCK  Information Technology   F      F  10966000000   500
# 7   F    STOCK  Information Technology   F      F  10966000000   425
# 8   F    STOCK  Information Technology   F      F  10966000000  2131
# 9   F    STOCK  Information Technology   F      F  10966000000   400
# 10  F    STOCK  Information Technology   F      F  10966000000  5949
# 11  F    STOCK  Information Technology   F      F  10966000000   941
#
#       1D After    3D After    5D After  1D Price  3D Price  5D Price  \
# 0   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 1   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 2   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 3   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 4   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 5   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 6   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 7   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 8   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 9   2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 10  2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
# 11  2023-01-10  2023-01-12  2023-01-16     58.05      58.7     59.72
#
#     1D Performance  3D Performance  5D Performance  Distance       1PN  \
# 0             2.02            3.16            4.96     36.20  positive
# 1             2.02            3.16            4.96    532.69  positive
# 2             2.02            3.16            4.96    427.24  positive
# 3             2.02            3.16            4.96     40.60  positive
# 4             2.06            3.20            4.99     75.81  positive
# 5             2.06            3.20            4.99     93.39  positive
# 6             2.06            3.20            4.99    234.04  positive
# 7             2.06            3.20            4.99    374.68  positive
# 8             2.06            3.20            4.99     93.39  positive
# 9             2.06            3.20            4.99    532.91  positive
# 10            3.53            4.69            6.51    -19.74  positive
# 11            3.53            4.69            6.51    -19.74  positive
#
#          3PN       5PN WeekDay
# 0   positive  positive  Monday
# 1   positive  positive  Monday
# 2   positive  positive  Monday
# 3   positive  positive  Monday
# 4   positive  positive  Monday
# 5   positive  positive  Monday
# 6   positive  positive  Monday
# 7   positive  positive  Monday
# 8   positive  positive  Monday
# 9   positive  positive  Monday
# 10  positive  positive  Monday
# 11  positive  positive  Monday
